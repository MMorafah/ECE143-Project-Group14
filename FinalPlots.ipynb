# %%
import plotly.graph_objects as go
import pandas as pd
import plotly.express as px
import numpy as np

# %%
cd code/visualizations
# Out:
# /Users/zhouchenhao_819/Downloads/ECE143-Project--master/code/visualizations

# %%
from fitting_plot import *

# %%
# may need rerun to show the grpah 
fit_plot()
# Out:
# <div>
#
#
#             <div id="412d6994-d886-4c96-b586-96f87084a1e1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("412d6994-d886-4c96-b586-96f87084a1e1")) {
#                     Plotly.newPlot(
#                         '412d6994-d886-4c96-b586-96f87084a1e1',
# ...

# %%
from prediction_plot import *

# %%
# may need rerun to show the grpah 
prediction_plot()
# Out:
# <div>
#
#
#             <div id="ae9941f5-1880-47e1-90c4-9aef8c9034f1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ae9941f5-1880-47e1-90c4-9aef8c9034f1")) {
#                     Plotly.newPlot(
#                         'ae9941f5-1880-47e1-90c4-9aef8c9034f1',
# ...

# %%
from comparation_of_diseases import *

# %%
# may need rerun to show the grpah 
comp()
# Out:
# <div>
#
#
#             <div id="786bef0a-7a21-488c-aa1e-844415381ead" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("786bef0a-7a21-488c-aa1e-844415381ead")) {
#                     Plotly.newPlot(
#                         '786bef0a-7a21-488c-aa1e-844415381ead',
# ...

# %%
from weibo_cloud import *

# %%
main()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager
import geopandas
import datetime as dt
from ipywidgets import interact, fixed
import ipywidgets as widgits
import shapely

# %%
from plotter import *
from add_gaussian_noise import *
from format_flatten import *
from map_plot import *

# %%
# may need rerun to show the grpah 
map_plot()
# Out:
# ...
# interactive(children=(IntSlider(value=0, description='days_since_start', max=35), Checkbox(value=True, descrip…

# %%
from trend_plot import *

# %%
trend_plot()

# %%
from vis_curve_fit import *

# %%
vis_curve_fit()
# Out:
# /Users/zhouchenhao_819/Downloads/ECE143-Project--master/code/visualizations/vis_curve_fit.py:68: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# //anaconda3/lib/python3.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning:
#
# Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
